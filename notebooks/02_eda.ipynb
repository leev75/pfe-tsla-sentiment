# %% [markdown]
# # Step 2 — Exploratory Data Analysis
# **PFE: A Machine Learning Approach to Financial News Sentiment and Market Trend Prediction**
#
# ---
#
# ## Planned Analysis
# - [ ] Document volume per day / month / year
# - [ ] Source distribution over time
# - [ ] Text length distribution per source
# - [ ] Keyword frequency (Tesla, Elon Musk, earnings, etc.)
# - [ ] Correlation between document volume spikes and TSLA price movements
# - [ ] Missing trading day coverage
#
# > **Status:** 🔜 Pending — to be completed after literature review

# %%
# TODO: EDA implementation
pass
